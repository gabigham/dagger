# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
power_file = 'data/global_power_plant_database.csv'
power_df = pd.read_csv(power_file)
power_df['commissioning_year'] = round(power_df['commissioning_year'],0)
power_df = power_df[power_df['commissioning_year']>=1990]
power_df.head()
# Out:
#    country country_long            name   gppd_idnr  capacity_mw  latitude  \
# 16     DZA      Algeria          Annaba  WRI1023795         71.0   36.8924
# 17     DZA      Algeria           Arbaa  WRI1023777        560.0   36.5988
# 19     DZA      Algeria      Boufarik 2  WRI1023793        450.0   36.5960
# 20     DZA      Algeria      Boutelilis  WRI1023781        450.0   35.5658
# 22     DZA      Algeria  Hadjret Ennous  WRI1023768       1200.0   36.5767
#
#     longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 16     7.7634          Gas         NaN         NaN  ...
# 17     3.1375          Gas         Oil         NaN  ...
# 19     2.8780          Gas         NaN         NaN  ...
# 20    -0.9386          Gas         NaN         NaN  ...
# 22     2.0797          Gas         Oil         NaN  ...
#
#                                                   url  geolocation_source  \
# 16  http://www.auptde.org/NewsDetails.aspx?lang=en...               GEODB
# 17  http://www.auptde.org/NewsDetails.aspx?lang=en...               GEODB
# 19  http://www.auptde.org/NewsDetails.aspx?lang=en...                 KTH
# 20  http://www.auptde.org/NewsDetails.aspx?lang=en...               GEODB
# 22  http://www.auptde.org/NewsDetails.aspx?lang=en...               GEODB
#
#     wepp_id year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 16  1029479                   NaN                 NaN                 NaN
# 17  1069669                   NaN                 NaN                 NaN
# 19  1029484                   NaN                 NaN                 NaN
# 20  1099563                   NaN                 NaN                 NaN
# 22  1044377                   NaN                 NaN                 NaN
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 16                 NaN                  NaN                  NaN
# 17                 NaN                  NaN                  NaN
# 19                 NaN                  NaN                  NaN
# 20                 NaN                  NaN                  NaN
# 22                 NaN                  NaN                  NaN
#
#     estimated_generation_gwh
# 16                293.864879
# 17               2317.807497
# 19               1862.523882
# 20               1862.523882
# 22               4966.730351
#
# [5 rows x 24 columns]

# %%
power_df.describe()
# Out:
#         capacity_mw      latitude     longitude  commissioning_year  \
# count  11515.000000  11515.000000  11515.000000        11515.000000
# mean     222.648034     28.173035    -37.560671         2008.122188
# std      573.133566     22.341832     76.243356            7.301999
# min        1.000000    -45.793400   -171.712400         1990.000000
# 25%        4.000000     26.068650    -92.667100         2003.000000
# 50%       20.000000     36.137200    -71.624600         2010.000000
# 75%      145.100000     41.504150      6.562350         2014.000000
# max    22500.000000     71.292000    179.388700         2018.000000
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count            7998.000000          3901.000000          4350.000000
# mean             2017.035259           528.417519           494.518644
# std                 0.248556          1738.171641          1703.470303
# min              2015.000000          -468.860000          -493.746000
# 25%              2017.000000             2.002000             2.108500
# 50%              2017.000000            23.210000            18.370000
# 75%              2017.000000           229.791000           202.896500
# max              2018.000000         27586.200000         28127.000000
#
#        generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# count          4882.000000          5791.000000          6138.000000
# mean            507.985530           451.203952           447.798807
# std            1739.740994          1642.943508          1637.632055
# min            -531.676000          -572.652000          -623.387000
# 25%               2.411250             2.474515             2.945500
# 50%              16.579500            13.082000            12.935000
# 75%             196.861750           156.467500           153.303000
# max           30539.000000         30015.000000         35116.000000
#
#        estimated_generation_gwh
# count               7072.000000
# mean                1111.007336
# std                 2943.161072
# min                    0.000000
# 25%                    7.689736
# 50%                   48.932036
# 75%                  606.047104
# max                92452.570325

# %%
power_df.hist(column='commissioning_year')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002276380E860>]],
#       dtype=object)

# %%
power_grp = power_df.groupby('commissioning_year').sum().reset_index()
power_grp.head()
# Out:
#    commissioning_year  capacity_mw   latitude   longitude  \
# 0              1990.0    30136.119  5941.6398 -11167.2180
# 1              1991.0    28221.186  5084.2376  -7886.7883
# 2              1992.0    41230.782  5871.9611  -6152.6692
# 3              1993.0    23288.830  5537.7226  -7076.8604
# 4              1994.0    50509.345  5644.7592  -6104.3374
#
#    year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0               294486.0         76243.896386         78131.966643
# 1               219860.0         73646.614517         60530.204822
# 2               219862.0         49708.817048         45029.190475
# 3               219862.0         37549.766443         47214.853531
# 4               225910.0         54810.054824         49115.085157
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0         78423.486640         77816.634719         74026.502840
# 1         67622.938533         68794.545318         78520.617866
# 2         48244.815599         47681.938988         43615.124620
# 3         47723.491191         42118.483223         43369.393914
# 4         56331.879954         40536.878761         48225.992067
#
#    estimated_generation_gwh
# 0              48652.973026
# 1              32916.123469
# 2             120623.726175
# 3              43000.974116
# 4             162751.682095

# %%
plt.scatter(power_grp['commissioning_year'],power_grp['capacity_mw'])
