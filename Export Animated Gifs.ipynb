# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
matplotlib.use('Agg')
from merge_data import merge_data
import numpy as np
import pandas as pd
import os
from config import (census_key, gkey)
import gmaps

# %%
#os.chdir('C://Users//adam//Desktop//dagger')

full_df, consump = merge_data()

# %%
full_df.head()
# Out:
#      Country  Year    HDI  Population  capacity_mw
# 0    Algeria  1990  0.577  25758869.0         0.00
# 1  Argentina  1990  0.704  32618651.0       761.02
# 2    Armenia  1990  0.631   3538171.0         0.00
# 3    Austria  1990  0.795   7677850.0        13.00
# 4    Bahrain  1990  0.746    495931.0         0.00

# %%
def animate(i):
    x.append(xs[i])
    y.append(ys[i])
    s.append(ss[i]/1000)
    sc.set_offsets(np.c_[x,y])
    sc.set_sizes(s)
    ax.legend(grf_data['Country'] + " " + x[i] +" " + size_ax + " " + str(s[i]))

# %%
for c in set(full_df['Country']):
    x_ax = 'Year'
    y_ax = 'HDI'
    size_ax = 'capacity_mw'
    
    grf_data = full_df[full_df['Country']==c].reset_index()

    fig, ax = plt.subplots()
    x,y,s  = [],[],[]
    sc = ax.scatter(x,y,s=s)

    xs = grf_data[x_ax]
    ys = grf_data[y_ax]
    ss = grf_data[size_ax]
    plt.xlim(int(xs.min()),int(xs.max()))#set to min and max
    plt.ylim(ys.min(),ys.max())#set to min and max
    ani = FuncAnimation(fig, animate, interval=100, repeat=True) 
    try:
        ani.save('output/'+c+ ' '+y_ax+'.gif', writer='pillow')
    except:
        pass
# Out:
# C:\Users\adam\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\adam\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ...

# %%
# Out:
# <img src="data:image/png;base64,..." width="639.6296748146958">
